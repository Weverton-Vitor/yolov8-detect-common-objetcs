# %%
# !pip install ultralytics
# !pip install pdf2image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 18.7 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO
import os
from pdf2image import convert_from_path
from PIL import Image

# %%
model = YOLO('yolov8n.pt')

# %% [markdown]
# Sobre os warnings abaixo, é por conta de um arquivo que vem do labemImg que seriam as classes, ele vem mais do que o extintor por exemplo, basta ajeitar isto, mas está funcionando como deve.

# %% [markdown]
# Esse modelo foi treinado dia 31/05/2023 para mostrar os detalhes.
# Dito isso, já testamos usar o imgsz no valor de 10 mil, mas sem melhoras, além de requerir um maior tempo de processamento, deixamos 10 epochs e com o batch 8 por conta da memória.

# %%
results = model.train(
   data='/kaggle/input/plantas-arquitetonicas/plantas/data.yaml',
   imgsz=640,
   epochs=100,
   batch=32,
   name='yolov8n_extintor_saidas')
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %% [markdown]
# Trecho que realiza a predição em uma imagem ou vídeo.

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/detect/yolov8n_extintor_saidas/weights/best.pt source=/kaggle/input/plantas-arquitetonicas/plantas/test/images/isaac_image1698862766045559_png.rf.c06134657a3bd78187495e0b934766df.jpg save=True imgsz=640 name=yolov8n_inferencia show_labels=True
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/1 /kaggle/input/plantas-arquitetonicas/plantas/test/images/isaac_image1698862766045559_png.rf.c06134657a3bd78187495e0b934766df.jpg: 640x640 2 extintoress, 66 saida_emergencias, 38.0ms
# Speed: 3.9ms preprocess, 38.0ms inference, 1526.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/yolov8n_inferencia2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !base64 /kaggle/input/plantas-arquitetonicas/plantas/test/images/isaac_image1698862766045559_png.rf.c06134657a3bd78187495e0b934766df.jpg | curl -d @- \
  "https://detect.roboflow.com/cv-bombeiros/3?api_key=B7XMJlmZyRJphntXLiFq"
# Out:
# {"time":0.039243121000026804,"image":{"width":640,"height":640},"predictions":[{"x":215.0,"y":341.0,"width":28.0,"height":24.0,"confidence":0.9002993106842041,"class":"extintores","class_id":0,"detection_id":"6761c8fa-915b-4c42-ac1e-08079e316422"},{"x":188.0,"y":340.0,"width":28.0,"height":22.0,"confidence":0.8705171346664429,"class":"extintores","class_id":0,"detection_id":"2ec7fe07-dec6-4ac1-9b26-f685ef0c8b07"},{"x":76.0,"y":393.0,"width":46.0,"height":26.0,"confidence":0.8474154472351074,"class":"saida_emergencia","class_id":1,"detection_id":"af4a8cdf-5203-4f9d-91f6-de2173202c8f"},{"x":366.5,"y":379.0,"width":45.0,"height":24.0,"confidence":0.750087559223175,"class":"saida_emergencia","class_id":1,"detection_id":"d29b2253-f4ee-4a37-9e00-03e660028f5a"}]}
